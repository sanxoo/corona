# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("postgresql://emma:1dls1ekfr@192.168.203.30/emma")
df = pd.read_sql_query("select * from corona_per_sido where stdday = '2022-09-02'", engine)

# %%
df.sort_values(by=["defcnt"], inplace=True, ascending=False)
df = df[df.gubun != "합계"]
df
# Out:
#         stdday gubun   defcnt  deathcnt  incdec  localocccnt  overflowcnt  \
# 9   2022-09-02    경기  6288986      6827   23629        23605           24
# 17  2022-09-02    서울  4589795      5263   15564        15554           10
# 2   2022-09-02    경남  1411572      1413    5364         5348           16
# 16  2022-09-02    부산  1408249      2374    4769         4763            6
# 14  2022-09-02    인천  1347343      1484    5178         5103           75
# 3   2022-09-02    경북  1047388      1564    4703         4676           27
# 15  2022-09-02    대구  1006027      1491    5069         5064            5
# 6   2022-09-02    충남   939654      1114    4357         4308           49
# 5   2022-09-02    전북   791231       946    3128         3099           29
# 4   2022-09-02    전남   780292       625    3470         3460           10
# 7   2022-09-02    충북   727840       815    3029         3021            8
# 13  2022-09-02    광주   692562       623    2507         2493           14
# ...

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="NanumGothic")

# %%
df.plot.bar(x="gubun", y=["incdec", "deathcnt"])
# Out:
# <AxesSubplot: xlabel='gubun'>
